# %%
import pandas as pd
import numpy as np
import datetime as dt
from time import strptime

# %% [markdown]
# ### Twitter
#
# Read in data export from twitter platform, wrangle, and export cleaned csv

# %%
# 1/31 - 2/13
twitter = pd.read_csv('twitter_weekly_pull.csv')
print(twitter.info())
twitter.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 40 columns):
# Tweet id                        150 non-null float64
# Tweet permalink                 150 non-null object
# Tweet text                      150 non-null object
# time                            150 non-null object
# impressions                     150 non-null int64
# engagements                     150 non-null int64
# engagement rate                 150 non-null float64
# retweets                        150 non-null int64
# replies                         150 non-null int64
# likes                           150 non-null int64
# user profile clicks             150 non-null int64
# url clicks                      150 non-null int64
# hashtag clicks                  150 non-null int64
# detail expands                  150 non-null int64
# permalink clicks                150 non-null int64
# app opens                       150 non-null int64
# app installs                    150 non-null int64
# follows                         150 non-null int64
# email tweet                     150 non-null int64
# dial phone                      150 non-null int64
# media views                     150 non-null int64
# media engagements               150 non-null int64
# promoted impressions            150 non-null object
# promoted engagements            150 non-null object
# promoted engagement rate        150 non-null object
# promoted retweets               150 non-null object
# promoted replies                150 non-null object
# promoted likes                  150 non-null object
# promoted user profile clicks    150 non-null object
# promoted url clicks             150 non-null object
# promoted hashtag clicks         150 non-null object
# promoted detail expands         150 non-null object
# promoted permalink clicks       150 non-null object
# promoted app opens              150 non-null object
# promoted app installs           150 non-null object
# promoted follows                150 non-null object
# promoted email tweet            150 non-null object
# promoted dial phone             150 non-null object
# promoted media views            150 non-null object
# promoted media engagements      150 non-null object
# dtypes: float64(2), int64(17), object(21)
# memory usage: 47.0+ KB
# None
#        Tweet id                                    Tweet permalink  \
# 0  1.095820e+18  https://twitter.com/Total_Bellas/status/109581...
# 1  1.095770e+18  https://twitter.com/Total_Bellas/status/109577...
# 2  1.095400e+18  https://twitter.com/Total_Bellas/status/109539...
# 3  1.095370e+18  https://twitter.com/Total_Bellas/status/109536...
# 4  1.095040e+18  https://twitter.com/Total_Bellas/status/109503...
#
#                                           Tweet text                    time  \
# 0  Tag your brunch buddy! 🍹 (And take them to see...  2019-02-13 23:00 +0000
# 1  Tag your #Galentine for this year, #BellaArmy!...  2019-02-13 20:00 +0000
# 2  @crzylikeafox86 Way to make #TotalBellas trivi...  2019-02-12 19:03 +0000
# 3  What pose makes you feel strong &amp; beautifu...  2019-02-12 17:00 +0000
# 4  What scared the 💩 out of Nikki while she was t...  2019-02-11 19:20 +0000
#
#    impressions  engagements  engagement rate  retweets  replies  likes  \
# 0         5588          344         0.061560        30        5    178
# 1         9006          740         0.082167        51       10    362
# 2          260           19         0.073077         0        2      2
# 3         9196          944         0.102653        45       21    457
# 4         5895          206         0.034945        12       27     74
#
#               ...              promoted hashtag clicks  \
# 0             ...                                    -
# 1             ...                                    -
# 2             ...                                    -
# 3             ...                                    -
# 4             ...                                    -
#
#    promoted detail expands  promoted permalink clicks  promoted app opens  \
# 0                        -                          -                   -
# 1                        -                          -                   -
# 2                        -                          -                   -
# 3                        -                          -                   -
# 4                        -                          -                   -
#
#    promoted app installs  promoted follows  promoted email tweet  \
# 0                      -                 -                     -
# 1                      -                 -                     -
# 2                      -                 -                     -
# 3                      -                 -                     -
# 4                      -                 -                     -
#
#    promoted dial phone  promoted media views  promoted media engagements
# 0                    -                     -                           -
# 1                    -                     -                           -
# 2                    -                     -                           -
# 3                    -                     -                           -
# 4                    -                     -                           -
#
# [5 rows x 40 columns]

# %%
# filter out unneeded columns
twitter = twitter.filter(['Tweet permalink', 'Tweet text', 'time', 'impressions', 'engagements',
                          'engagement rate', 'retweets', 'replies', 'likes', 'media views', 'media engagements'])
twitter.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 11 columns):
# Tweet permalink      150 non-null object
# Tweet text           150 non-null object
# time                 150 non-null object
# impressions          150 non-null int64
# engagements          150 non-null int64
# engagement rate      150 non-null float64
# retweets             150 non-null int64
# replies              150 non-null int64
# likes                150 non-null int64
# media views          150 non-null int64
# media engagements    150 non-null int64
# dtypes: float64(1), int64(7), object(3)
# memory usage: 13.0+ KB

# %%
## create new columns needed

#create 'post type' column indicating whether reply or original post
twitter['post type'] = twitter['Tweet text'].map(lambda x: "reply" if x[0] == '@' else "post")

# create 'vis eng' column calculating visible engagements by adding retweets, replies, likes
twitter['vis eng'] = twitter['retweets'] + twitter['replies'] + twitter['likes']

# create 'view Rate' and 'completion rate' columns by dividing media views and engagements by impressions, respectively
twitter['view rate'] = twitter['media views']/twitter['impressions']
twitter['completion rate'] = twitter['media engagements']/twitter['impressions']

# convert 'date' column to datetime
twitter['time'] = pd.to_datetime(twitter['time'])

# create 'in-show' column - 203 aired on 01/27/19 - 9PM EST, so tweets between GMT 1/28 2AM - 6AM are "in-show"
# 204 aired on 2/10/19 - 9PM EST, so tweets between GMT 2/11 2AM - 6AM are "in-show"
twitter['in-show'] = twitter['time'].map(lambda x: "in-show" if x >= pd.to_datetime(['2019-01-28 02:00:00']) and x <= pd.to_datetime(['2019-01-28 06:00:00']) else "in-show" if x >= pd.to_datetime(['2019-02-03 02:00:00']) and x <= pd.to_datetime(['2019-02-03 06:00:00']) else "not")

# create empty 'Votes' column
twitter['votes'] = np.nan

twitter['time'] = twitter['time'].dt.normalize()
print(twitter['time'].dtype)

#Phase = premiere/continuity/finale
twitter['phase'] = twitter['time'].map(lambda x: "premiere" if x >= pd.to_datetime(['2019-01-10 00:00:00']) and x <= pd.to_datetime(['2019-01-16 11:59:00']) else "continuity" if (x >= pd.to_datetime(['2019-01-17 00:00:00']) and x <= pd.to_datetime(['2019-01-31 00:00:00'])) or (x >= pd.to_datetime(['2019-02-07 00:00:00']) and x <= pd.to_datetime(['2019-03-21 00:00:00'])) else "finale" if x >= pd.to_datetime(['2019-03-21 00:00:00']) and x <= pd.to_datetime(['2019-03-28 00:00:00']) else "hiatus")

# add 'episode' column assigning episode number: first 2 digits = season number, last 2 digits = episode number
twitter['episode'] = twitter['time'].map(lambda x: "403" if x >= pd.to_datetime(['2019-01-24 00:00:00']) and x <= pd.to_datetime(['2019-01-30 11:59:00']) else "404" if x >= pd.to_datetime(['2019-02-07 00:00:00']) and x <= pd.to_datetime(['2019-02-13 11:59:00']) else "none")

#messaging = tune-in/awareness/catch-up
twitter['messaging'] = twitter['Tweet text'].map(lambda x: "tune-in" if 'Sunday' in x else "tune-in" if 'tomorrow' in x else "tune-in" if 'tonight' in x else "tune-in" if 'new' in x else "Catch-Up" if 'catch up' in x else "Catch-Up" if 'Demand' in x else "Awareness")

twitter['content series'] = np.nan

twitter['asset type'] = np.nan

twitter['subject'] = np.nan

print(twitter.info())
twitter.head()
# Out:
# datetime64[ns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 23 columns):
# Tweet permalink      150 non-null object
# Tweet text           150 non-null object
# time                 150 non-null datetime64[ns]
# impressions          150 non-null int64
# engagements          150 non-null int64
# engagement rate      150 non-null float64
# retweets             150 non-null int64
# replies              150 non-null int64
# likes                150 non-null int64
# media views          150 non-null int64
# media engagements    150 non-null int64
# post type            150 non-null object
# vis eng              150 non-null int64
# view rate            150 non-null float64
# completion rate      150 non-null float64
# in-show              150 non-null object
# votes                0 non-null float64
# phase                150 non-null object
# episode              150 non-null object
# messaging            150 non-null object
# content series       0 non-null float64
# asset type           0 non-null float64
# subject              0 non-null float64
# dtypes: datetime64[ns](1), float64(7), int64(8), object(7)
# memory usage: 27.0+ KB
# None
#                                      Tweet permalink  \
# 0  https://twitter.com/Total_Bellas/status/109581...
# 1  https://twitter.com/Total_Bellas/status/109577...
# 2  https://twitter.com/Total_Bellas/status/109539...
# 3  https://twitter.com/Total_Bellas/status/109536...
# 4  https://twitter.com/Total_Bellas/status/109503...
#
#                                           Tweet text       time  impressions  \
# 0  Tag your brunch buddy! 🍹 (And take them to see... 2019-02-13         5588
# 1  Tag your #Galentine for this year, #BellaArmy!... 2019-02-13         9006
# 2  @crzylikeafox86 Way to make #TotalBellas trivi... 2019-02-12          260
# 3  What pose makes you feel strong &amp; beautifu... 2019-02-12         9196
# 4  What scared the 💩 out of Nikki while she was t... 2019-02-11         5895
#
#    engagements  engagement rate  retweets  replies  likes  media views  \
# 0          344         0.061560        30        5    178         1361
# 1          740         0.082167        51       10    362         2006
# 2           19         0.073077         0        2      2           46
# 3          944         0.102653        45       21    457          313
# 4          206         0.034945        12       27     74            0
#
#     ...    view rate completion rate  in-show  votes       phase episode  \
# 0   ...     0.243558        0.020759      not    NaN  continuity     404
# 1   ...     0.222740        0.027981      not    NaN  continuity     404
# 2   ...     0.176923        0.030769      not    NaN  continuity     404
# 3   ...     0.034037        0.034037      not    NaN  continuity     404
# 4   ...     0.000000        0.000000      not    NaN  continuity     404
#
#    messaging content series asset type subject
# 0  Awareness            NaN        NaN     NaN
# 1  Awareness            NaN        NaN     NaN
# 2  Awareness            NaN        NaN     NaN
# 3  Awareness            NaN        NaN     NaN
# 4  Awareness            NaN        NaN     NaN
#
# [5 rows x 23 columns]

# %%
#standardize column names i.e. make all lowercase
twitter.columns = map(str.lower, twitter.columns)
twitter.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 23 columns):
# tweet permalink      150 non-null object
# tweet text           150 non-null object
# time                 150 non-null datetime64[ns]
# impressions          150 non-null int64
# engagements          150 non-null int64
# engagement rate      150 non-null float64
# retweets             150 non-null int64
# replies              150 non-null int64
# likes                150 non-null int64
# media views          150 non-null int64
# media engagements    150 non-null int64
# post type            150 non-null object
# vis eng              150 non-null int64
# view rate            150 non-null float64
# completion rate      150 non-null float64
# in-show              150 non-null object
# votes                0 non-null float64
# phase                150 non-null object
# episode              150 non-null object
# messaging            150 non-null object
# content series       0 non-null float64
# asset type           0 non-null float64
# subject              0 non-null float64
# dtypes: datetime64[ns](1), float64(7), int64(8), object(7)
# memory usage: 27.0+ KB

# %%
#reorder columns
twitter = twitter[['post type', 'tweet permalink', 'tweet text', 'episode', 'time', 'in-show','phase','messaging',
                   'content series','asset type','subject','impressions','engagements', 'engagement rate', 'retweets', 
                   'replies', 'likes', 'votes', 'vis eng','media views', 'media engagements', 'view rate', 'completion rate']]
twitter.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 23 columns):
# post type            150 non-null object
# tweet permalink      150 non-null object
# tweet text           150 non-null object
# episode              150 non-null object
# time                 150 non-null datetime64[ns]
# in-show              150 non-null object
# phase                150 non-null object
# messaging            150 non-null object
# content series       0 non-null float64
# asset type           0 non-null float64
# subject              0 non-null float64
# impressions          150 non-null int64
# engagements          150 non-null int64
# engagement rate      150 non-null float64
# retweets             150 non-null int64
# replies              150 non-null int64
# likes                150 non-null int64
# votes                0 non-null float64
# vis eng              150 non-null int64
# media views          150 non-null int64
# media engagements    150 non-null int64
# view rate            150 non-null float64
# completion rate      150 non-null float64
# dtypes: datetime64[ns](1), float64(7), int64(8), object(7)
# memory usage: 27.0+ KB

# %%
# convert new dataframe to csv "twitter_weekly.csv"
twitter.to_csv('twitter_weekly.csv')

# %% [markdown]
# ### Nielsen
# Read in data export from Nielsen UI, wrangle and write to csv.

# %%
# read in file for current week's episode
# air time: 2/10/19 - 9PM EST
nielsen = pd.read_csv('nielsen_weekly_pull.csv')
nielsen.info()
nielsen.head(20)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2344 entries, 0 to 2343
# Data columns (total 14 columns):
# Social Content Ratings    2336 non-null object
# Unnamed: 1                2334 non-null object
# Unnamed: 2                2325 non-null object
# Unnamed: 3                2325 non-null object
# Unnamed: 4                2325 non-null object
# Unnamed: 5                2321 non-null object
# Unnamed: 6                2321 non-null object
# Unnamed: 7                2319 non-null object
# Unnamed: 8                2319 non-null object
# Unnamed: 9                2319 non-null object
# Unnamed: 10               2319 non-null object
# Unnamed: 11               2319 non-null object
# Unnamed: 12               2319 non-null object
# Unnamed: 13               1927 non-null object
# dtypes: object(14)
# memory usage: 256.5+ KB
#                                Social Content Ratings  \
# 0                       http://scr.nielsensocial.com/
# 1   Copyright 2019 The Nielsen Company.  All right...
# 2                                                 NaN
# 3                                             Network
# 4                                             Program
# 5                                  Program Genre Type
# 6                                       Season Number
# 7                                             Episode
# 8                                      Episode Number
# 9                                      EPG Program ID
# 10                                     EPG Episode ID
# 11                                           Air Date
# 12                                 Airtime Start Time
# 13                                 Duration (Minutes)
# 14                                           Live/New
# 15                                        Report Type
# 16                                                NaN
# 17                                                NaN
# 18                                            Twitter
# 19                                                NaN
#
#                                   Unnamed: 1        Unnamed: 2  \
# 0                                        NaN               NaN
# 1                                        NaN               NaN
# 2                                        NaN               NaN
# 3                                          E               NaN
# 4                               Total Bellas               NaN
# 5   Reality Series; Docs & Special Interests               NaN
# 6                                          4               NaN
# 7                               It's My Life               NaN
# 8                                          4               NaN
# 9                             SH024910700000               NaN
# 10                            EP024910700032               NaN
# 11                                   2/10/19               NaN
# 12                              09:00 PM EST               NaN
# 13                                        60               NaN
# 14                                       Yes               NaN
# 15                        Tweets (Verbatims)               NaN
# 16                                       NaN               NaN
# 17                            Unique Authors  Original Content
# 18                                       234               392
# 19                                       NaN          Retweets
#
#          Unnamed: 3        Unnamed: 4 Unnamed: 5    Unnamed: 6 Unnamed: 7  \
# 0               NaN               NaN        NaN           NaN        NaN
# 1               NaN               NaN        NaN           NaN        NaN
# 2               NaN               NaN        NaN           NaN        NaN
# 3               NaN               NaN        NaN           NaN        NaN
# 4               NaN               NaN        NaN           NaN        NaN
# 5               NaN               NaN        NaN           NaN        NaN
# 6               NaN               NaN        NaN           NaN        NaN
# 7               NaN               NaN        NaN           NaN        NaN
# 8               NaN               NaN        NaN           NaN        NaN
# 9               NaN               NaN        NaN           NaN        NaN
# 10              NaN               NaN        NaN           NaN        NaN
# 11              NaN               NaN        NaN           NaN        NaN
# 12              NaN               NaN        NaN           NaN        NaN
# 13              NaN               NaN        NaN           NaN        NaN
# 14              NaN               NaN        NaN           NaN        NaN
# 15              NaN               NaN        NaN           NaN        NaN
# 16              NaN               NaN        NaN           NaN        NaN
# 17  Unique Engagers  Total Engagement    Uniques  Interactions        NaN
# 18             4597             11531       4754         11923        NaN
# 19              576              1284        NaN           NaN        NaN
#
#    Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 12 Unnamed: 13
# 0         NaN        NaN         NaN         NaN         NaN         NaN
# 1         NaN        NaN         NaN         NaN         NaN         NaN
# 2         NaN        NaN         NaN         NaN         NaN         NaN
# 3         NaN        NaN         NaN         NaN         NaN         NaN
# 4         NaN        NaN         NaN         NaN         NaN         NaN
# 5         NaN        NaN         NaN         NaN         NaN         NaN
# 6         NaN        NaN         NaN         NaN         NaN         NaN
# 7         NaN        NaN         NaN         NaN         NaN         NaN
# 8         NaN        NaN         NaN         NaN         NaN         NaN
# 9         NaN        NaN         NaN         NaN         NaN         NaN
# 10        NaN        NaN         NaN         NaN         NaN         NaN
# 11        NaN        NaN         NaN         NaN         NaN         NaN
# 12        NaN        NaN         NaN         NaN         NaN         NaN
# 13        NaN        NaN         NaN         NaN         NaN         NaN
# 14        NaN        NaN         NaN         NaN         NaN         NaN
# 15        NaN        NaN         NaN         NaN         NaN         NaN
# 16        NaN        NaN         NaN         NaN         NaN         NaN
# 17        NaN        NaN         NaN         NaN         NaN         NaN
# 18        NaN        NaN         NaN         NaN         NaN         NaN
# 19        NaN        NaN         NaN         NaN         NaN         NaN

# %%
# toss row indices 0-9 into a new dataframe and isolate episode name
episode_details = nielsen.iloc[:13]
episode_details['episode'] = episode_details.iat[6,1] + str('0') + episode_details.iat[8,1]
episode_details['name'] = episode_details.iat[7,1]
episode_details['air date'] = episode_details.iat[11,1]
episode_details['air time'] = episode_details.iat[12,1]
episode_details.drop(episode_details.index[1:],inplace=True)
episode_details = episode_details.loc[:, ['episode','name','air date','air time']]
episode_details
# Out:
# /Users/christina.caddel/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/christina.caddel/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /Users/christina.caddel/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /Users/christina.caddel/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/christina.caddel/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py:3694: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)
#   episode          name air date      air time
# 0     404  It's My Life  2/10/19  09:00 PM EST

# %%
# bring up row index 17 as header and drop row indices 0-16
nielsen.drop(nielsen.index[:17], inplace=True)
nielsen.columns = nielsen.iloc[0]
nielsen = nielsen[1:]
nielsen = nielsen.reset_index(drop = True)
nielsen.head(15)
# Out:
# 17              NaN                       Unique Authors Original Content  \
# 0           Twitter                                  234              392
# 1               NaN                                  NaN         Retweets
# 2               NaN                                  NaN          Replies
# 3               NaN                                  NaN           Quotes
# 4               NaN                                  NaN            Likes
# 5               NaN                                  NaN              NaN
# 6            Tweets                                  NaN              NaN
# 7              User                     User Profile Url          User ID
# 8       UsmanKhera1      https://twitter.com/UsmanKhera1      9.35895E+17
# 9          Awe_Heck         https://twitter.com/Awe_Heck       2972451204
# 10       lola_wanda       https://twitter.com/lola_wanda        566795599
# 11        mike21756        https://twitter.com/mike21756        381244615
# 12  ArghaBa48816898  https://twitter.com/ArghaBa48816898       1.0597E+18
# 13    NikkiAndArtem    https://twitter.com/NikkiAndArtem      7.13936E+17
# 14    _whatisthe411    https://twitter.com/_whatisthe411      9.84077E+17
#
# 17 Unique Engagers   Total Engagement     Uniques          Interactions  \
# 0             4597              11531        4754                 11923
# 1              576               1284         NaN                   NaN
# 2              389                529         NaN                   NaN
# 3               88                113         NaN                   NaN
# 4             4209               9605         NaN                   NaN
# 5              NaN                NaN         NaN                   NaN
# 6              NaN                NaN         NaN                   NaN
# 7        Followers  Time Sent (Local)  Local Date       Time Sent (GMT)
# 8               17    07:04:19 PM EST     2/10/19  2019-02-11T00:04:19Z
# 9               20    07:46:12 PM EST     2/10/19  2019-02-11T00:46:12Z
# 10              27    07:54:58 PM EST     2/10/19  2019-02-11T00:54:58Z
# 11            2182    08:02:32 PM EST     2/10/19  2019-02-11T01:02:32Z
# 12               1    08:33:02 PM EST     2/10/19  2019-02-11T01:33:02Z
# 13             280    08:40:31 PM EST     2/10/19  2019-02-11T01:40:31Z
# 14              66    09:39:42 PM EST     2/10/19  2019-02-11T02:39:42Z
#
# 17          NaN                                                NaN  \
# 0           NaN                                                NaN
# 1           NaN                                                NaN
# 2           NaN                                                NaN
# 3           NaN                                                NaN
# 4           NaN                                                NaN
# 5           NaN                                                NaN
# 6           NaN                                                NaN
# 7      Tweet ID                                              Tweet
# 8   1.09475E+18  RT @BellaTwins: An all NEW episode of totalbel...
# 9   1.09476E+18  @BellaTwins I can't wait! Oh and I got my Bell...
# 10  1.09476E+18  RT @BellaTwins: An all NEW episode of totalbel...
# 11  1.09476E+18  RT @BellaTwins: An all NEW episode of totalbel...
# 12  1.09477E+18                      @BellaTwins Happy propose day
# 13  1.09477E+18  RT @BellaTwins: An all NEW episode of totalbel...
# 14  1.09479E+18  RT @BellaTwins: An all NEW episode of totalbel...
#
# 17                                               NaN               NaN  \
# 0                                                NaN               NaN
# 1                                                NaN               NaN
# 2                                                NaN               NaN
# 3                                                NaN               NaN
# 4                                                NaN               NaN
# 5                                                NaN               NaN
# 6                                                NaN               NaN
# 7                                          Tweet URL  Interaction Type
# 8   https://twitter.com/statuses/1094748932532592640        engagement
# 9   https://twitter.com/statuses/1094759470318653441        engagement
# 10  https://twitter.com/statuses/1094761677722210305        engagement
# 11  https://twitter.com/statuses/1094763582804410369        engagement
# 12  https://twitter.com/statuses/1094771257483001857        engagement
# 13  https://twitter.com/statuses/1094773142017306624        engagement
# 14  https://twitter.com/statuses/1094788033646391297        engagement
#
# 17         NaN          NaN                                               NaN
# 0          NaN          NaN                                               NaN
# 1          NaN          NaN                                               NaN
# 2          NaN          NaN                                               NaN
# 3          NaN          NaN                                               NaN
# 4          NaN          NaN                                               NaN
# 5          NaN          NaN                                               NaN
# 6          NaN          NaN                                               NaN
# 7   Tweet Type      Root ID                                          Root URL
# 8      retweet  1.09464E+18  https://twitter.com/statuses/1094638464073515008
# 9        reply  1.09464E+18  https://twitter.com/statuses/1094638464073515008
# 10     retweet  1.09464E+18  https://twitter.com/statuses/1094638464073515008
# 11     retweet  1.09464E+18  https://twitter.com/statuses/1094638464073515008
# 12       reply  1.09464E+18  https://twitter.com/statuses/1094638464073515008
# 13     retweet  1.09464E+18  https://twitter.com/statuses/1094638464073515008
# 14     retweet  1.09464E+18  https://twitter.com/statuses/1094638464073515008

# %%
# calculate value for total mentions and add as column
mentions = nielsen.iloc[8:]
nielsen['total mentions'] = mentions['Unique Authors'].count()

nielsen.head()
# Out:
# 17      NaN Unique Authors Original Content Unique Engagers Total Engagement  \
# 0   Twitter            234              392            4597            11531
# 1       NaN            NaN         Retweets             576             1284
# 2       NaN            NaN          Replies             389              529
# 3       NaN            NaN           Quotes              88              113
# 4       NaN            NaN            Likes            4209             9605
#
# 17 Uniques Interactions  NaN  NaN  NaN  NaN  NaN  NaN  NaN  total mentions
# 0     4754        11923  NaN  NaN  NaN  NaN  NaN  NaN  NaN            2318
# 1      NaN          NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN            2318
# 2      NaN          NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN            2318
# 3      NaN          NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN            2318
# 4      NaN          NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN            2318

# %%
# keep only relevant columns and drop all rows except first
nielsen = nielsen[['Unique Authors','Original Content','Unique Engagers','Interactions','total mentions']]
nielsen.drop(nielsen.index[1:], inplace=True)
nielsen.head()
# Out:
# 17 Unique Authors Original Content Unique Engagers Interactions  \
# 0             234              392            4597        11923
#
# 17  total mentions
# 0             2318

# %%
# rename and reorder columns
nielsen.columns = ['unique users','total social convos','unique authors/engagers','interactions','total mentions']
nielsen['episode'], nielsen['name'], nielsen['air date'], nielsen['air time'] = episode_details['episode'], episode_details['name'], episode_details['air date'], episode_details['air time']
nielsen = nielsen[['episode','name','air date','air time','unique users','total social convos','unique authors/engagers','interactions','total mentions']]
nielsen.head()
# Out:
#   episode          name air date      air time unique users  \
# 0     404  It's My Life  2/10/19  09:00 PM EST          234
#
#   total social convos unique authors/engagers interactions  total mentions
# 0                 392                    4597        11923            2318

# %%
nielsen.to_csv('nielsen_weekly.csv')

# %% [markdown]
# ### Facebook
# Read in data export from Facebook platform, wrangle, and write to csv.

# %%
fb = pd.read_csv('fb_weekly_pull.csv')
print(fb.info())
fb.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 54 columns):
# Post ID                                                                        35 non-null object
# Permalink                                                                      35 non-null object
# Post Message                                                                   35 non-null object
# Type                                                                           35 non-null object
# Countries                                                                      0 non-null float64
# Languages                                                                      0 non-null float64
# Posted                                                                         35 non-null object
# Audience Targeting                                                             35 non-null object
# Lifetime Post Total Reach                                                      36 non-null object
# Lifetime Post organic reach                                                    36 non-null object
# Lifetime Post Paid Reach                                                       36 non-null object
# Lifetime Post Total Impressions                                                36 non-null object
# Lifetime Post Organic Impressions                                              36 non-null object
# Lifetime Post Paid Impressions                                                 36 non-null object
# Lifetime Engaged Users                                                         36 non-null object
# Lifetime Matched Audience Targeting Consumers on Post                          36 non-null object
# Lifetime Matched Audience Targeting Consumptions on Post                       36 non-null object
# Lifetime Negative Feedback from Users                                          36 non-null object
# Lifetime Negative Feedback                                                     36 non-null object
# Lifetime Post Impressions by people who have liked your Page                   36 non-null object
# Lifetime Post reach by people who like your Page                               36 non-null object
# Lifetime Post Paid Impressions by people who have liked your Page              36 non-null object
# Lifetime Paid reach of a post by people who like your Page                     36 non-null object
# Lifetime People who have liked your Page and engaged with your post            36 non-null object
# Lifetime Organic views to 95%                                                  36 non-null object
# Lifetime Organic views to 95%.1                                                36 non-null object
# Lifetime Paid views to 95%                                                     36 non-null object
# Lifetime Paid views to 95%.1                                                   36 non-null object
# Lifetime Organic Video Views                                                   36 non-null object
# Lifetime Organic Video Views.1                                                 36 non-null object
# Lifetime Paid Video Views                                                      36 non-null object
# Lifetime Paid Video Views.1                                                    36 non-null object
# Lifetime Average time video viewed                                             36 non-null object
# Lifetime Video length                                                          36 non-null object
# Lifetime Talking About This (Post) by action type - share                      36 non-null object
# Lifetime Talking About This (Post) by action type - like                       35 non-null float64
# Lifetime Talking About This (Post) by action type - comment                    35 non-null float64
# Lifetime Post Stories by action type - share                                   36 non-null object
# Lifetime Post Stories by action type - like                                    35 non-null float64
# Lifetime Post Stories by action type - comment                                 35 non-null float64
# Lifetime Post Audience Targeting Unique Consumptions by Type - other clicks    36 non-null object
# Lifetime Post Audience Targeting Unique Consumptions by Type - link clicks     16 non-null float64
# Lifetime Post Audience Targeting Unique Consumptions by Type - video play      22 non-null float64
# Lifetime Post Audience Targeting Unique Consumptions by Type - photo view      4 non-null float64
# Lifetime Matched Audience Targeting Consumptions by Type - other clicks        36 non-null object
# Lifetime Matched Audience Targeting Consumptions by Type - link clicks         16 non-null float64
# Lifetime Matched Audience Targeting Consumptions by Type - video play          22 non-null float64
# Lifetime Matched Audience Targeting Consumptions by Type - photo view          4 non-null float64
# Lifetime Negative Feedback from Users by Type - hide_all_clicks                35 non-null object
# Lifetime Negative Feedback from Users by Type - hide_clicks                    35 non-null float64
# Lifetime Negative Feedback from Users by Type - report_spam_clicks             2 non-null float64
# Lifetime Negative Feedback by Type - hide_all_clicks                           35 non-null object
# Lifetime Negative Feedback by Type - hide_clicks                               35 non-null float64
# Lifetime Negative Feedback by Type - report_spam_clicks                        2 non-null float64
# dtypes: float64(16), object(38)
# memory usage: 15.3+ KB
# None
#                              Post ID  \
# 0                                NaN
# 1  1121717847895069_2277015872365255
# 2  1121717847895069_2266016210131888
# 3  1121717847895069_2273540462712796
# 4  1121717847895069_2266013050132204
#
#                                            Permalink  \
# 0                                                NaN
# 1  https://www.facebook.com/totalbellas/posts/227...
# 2  https://www.facebook.com/totalbellas/posts/226...
# 3  https://www.facebook.com/totalbellas/posts/227...
# 4  https://www.facebook.com/totalbellas/posts/226...
#
#                                         Post Message   Type  Countries  \
# 0                                                NaN    NaN        NaN
# 1  Parenting is a full-time job, and Brie is putt...   Link        NaN
# 2  A media frenzy won't scare Nikki. Brie on the ...  Video        NaN
# 3  From the ring to the runway, the Bella Twins a...  Video        NaN
# 4  Brie’s forcing Nikki to draw a line in the san...  Video        NaN
#
#    Languages         Posted Audience Targeting  \
# 0        NaN            NaN                NaN
# 1        NaN  2/13/19 18:13
# 2        NaN   2/12/19 9:00
# 3        NaN  2/11/19 17:12
# 4        NaN   2/11/19 9:00
#
#                            Lifetime Post Total Reach  \
# 0  Lifetime: The number of people who had your Pa...
# 1                                              30392
# 2                                              24411
# 3                                              28165
# 4                                            2566769
#
#                          Lifetime Post organic reach  \
# 0  Lifetime: The number of people who had your Pa...
# 1                                              30392
# 2                                              24411
# 3                                              28165
# 4                                              25106
#
#                             ...                            \
# 0                           ...
# 1                           ...
# 2                           ...
# 3                           ...
# 4                           ...
#
#   Lifetime Matched Audience Targeting Consumptions by Type - other clicks  \
# 0  Lifetime: The number of clicks anywhere in the...
# 1                                                825
# 2                                               1706
# 3                                               2223
# 4                                               7432
#
#   Lifetime Matched Audience Targeting Consumptions by Type - link clicks  \
# 0                                                NaN
# 1                                             1130.0
# 2                                               26.0
# 3                                                NaN
# 4                                                NaN
#
#   Lifetime Matched Audience Targeting Consumptions by Type - video play  \
# 0                                                NaN
# 1                                                NaN
# 2                                              511.0
# 3                                              850.0
# 4                                            46917.0
#
#   Lifetime Matched Audience Targeting Consumptions by Type - photo view  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Lifetime Negative Feedback from Users by Type - hide_all_clicks  \
# 0  Lifetime: The number of times people have give...
# 1                                                  3
# 2                                                  4
# 3                                                NaN
# 4                                                  8
#
#   Lifetime Negative Feedback from Users by Type - hide_clicks  \
# 0                                                NaN
# 1                                                4.0
# 2                                                3.0
# 3                                                3.0
# 4                                                5.0
#
#   Lifetime Negative Feedback from Users by Type - report_spam_clicks  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                1.0
#
#   Lifetime Negative Feedback by Type - hide_all_clicks  \
# 0  Lifetime: The number of people who have given ...
# 1                                                  3
# 2                                                  3
# 3                                                NaN
# 4                                                  8
#
#   Lifetime Negative Feedback by Type - hide_clicks  \
# 0                                              NaN
# 1                                              4.0
# 2                                              3.0
# 3                                              3.0
# 4                                              5.0
#
#   Lifetime Negative Feedback by Type - report_spam_clicks
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                1.0
#
# [5 rows x 54 columns]

# %%
#drop unwanted rows and columns
fb.drop(fb.index[0], inplace=True)
fb = fb.filter(['Permalink','Posted','Post Message','Type','Lifetime Post organic reach','Lifetime Post Organic Impressions','Lifetime Engaged Users','Lifetime Organic Video Views.1','Lifetime Organic views to 95%.1','Lifetime Talking About This (Post) by action type - like','Lifetime Talking About This (Post) by action type - comment','Lifetime Talking About This (Post) by action type - share'])
fb = fb.reset_index(drop=True)
fb.head()
# Out:
#                                            Permalink         Posted  \
# 0  https://www.facebook.com/totalbellas/posts/227...  2/13/19 18:13
# 1  https://www.facebook.com/totalbellas/posts/226...   2/12/19 9:00
# 2  https://www.facebook.com/totalbellas/posts/227...  2/11/19 17:12
# 3  https://www.facebook.com/totalbellas/posts/226...   2/11/19 9:00
# 4  https://www.facebook.com/totalbellas/posts/226...  2/10/19 17:00
#
#                                         Post Message   Type  \
# 0  Parenting is a full-time job, and Brie is putt...   Link
# 1  A media frenzy won't scare Nikki. Brie on the ...  Video
# 2  From the ring to the runway, the Bella Twins a...  Video
# 3  Brie’s forcing Nikki to draw a line in the san...  Video
# 4  Leave a 🙏 if Mama Bella's speaking the truth.\...  Video
#
#   Lifetime Post organic reach Lifetime Post Organic Impressions  \
# 0                       30392                             39400
# 1                       24411                             31636
# 2                       28165                             36936
# 3                       25106                             32214
# 4                       48040                             63224
#
#   Lifetime Engaged Users Lifetime Organic Video Views.1  \
# 0                   2190                              0
# 1                   2055                          11059
# 2                   2447                          14166
# 3                  45165                           8862
# 4                   6236                          24182
#
#   Lifetime Organic views to 95%.1  \
# 0                               0
# 1                            1232
# 2                            1499
# 3                            3206
# 4                           12645
#
#    Lifetime Talking About This (Post) by action type - like  \
# 0                                              668.0
# 1                                              414.0
# 2                                              319.0
# 3                                             1298.0
# 4                                              869.0
#
#    Lifetime Talking About This (Post) by action type - comment  \
# 0                                               16.0
# 1                                               12.0
# 2                                                5.0
# 3                                               89.0
# 4                                              100.0
#
#   Lifetime Talking About This (Post) by action type - share
# 0                                                 19
# 1                                                 12
# 2                                                 17
# 3                                                 83
# 4                                                 58

# %%
#rename columns
fb.columns = ['link','date posted','message','media type','reach','organic impressions','engagement','organic video views','organic video completes','likes','comments','shares']
fb.head()
# Out:
#                                                 link    date posted  \
# 0  https://www.facebook.com/totalbellas/posts/227...  2/13/19 18:13
# 1  https://www.facebook.com/totalbellas/posts/226...   2/12/19 9:00
# 2  https://www.facebook.com/totalbellas/posts/227...  2/11/19 17:12
# 3  https://www.facebook.com/totalbellas/posts/226...   2/11/19 9:00
# 4  https://www.facebook.com/totalbellas/posts/226...  2/10/19 17:00
#
#                                              message media type  reach  \
# 0  Parenting is a full-time job, and Brie is putt...       Link  30392
# 1  A media frenzy won't scare Nikki. Brie on the ...      Video  24411
# 2  From the ring to the runway, the Bella Twins a...      Video  28165
# 3  Brie’s forcing Nikki to draw a line in the san...      Video  25106
# 4  Leave a 🙏 if Mama Bella's speaking the truth.\...      Video  48040
#
#   organic impressions engagement organic video views organic video completes  \
# 0               39400       2190                   0                       0
# 1               31636       2055               11059                    1232
# 2               36936       2447               14166                    1499
# 3               32214      45165                8862                    3206
# 4               63224       6236               24182                   12645
#
#     likes  comments shares
# 0   668.0      16.0     19
# 1   414.0      12.0     12
# 2   319.0       5.0     17
# 3  1298.0      89.0     83
# 4   869.0     100.0     58

# %%
fb = fb.fillna(0)

cols = ['likes','comments','shares','reach','organic impressions','engagement','organic video views','organic video completes']

for col in cols:
    fb[col] = fb[col].astype(int)
    
fb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 12 columns):
# link                       35 non-null object
# date posted                35 non-null object
# message                    35 non-null object
# media type                 35 non-null object
# reach                      35 non-null int64
# organic impressions        35 non-null int64
# engagement                 35 non-null int64
# organic video views        35 non-null int64
# organic video completes    35 non-null int64
# likes                      35 non-null int64
# comments                   35 non-null int64
# shares                     35 non-null int64
# dtypes: int64(8), object(4)
# memory usage: 3.4+ KB

# %%
fb['date posted'] = pd.to_datetime(fb['date posted'])
fb['date posted'] = fb['date posted'].dt.normalize()
print(fb['date posted'].dtype)
fb.head()
# Out:
# datetime64[ns]
#                                                 link date posted  \
# 0  https://www.facebook.com/totalbellas/posts/227...  2019-02-13
# 1  https://www.facebook.com/totalbellas/posts/226...  2019-02-12
# 2  https://www.facebook.com/totalbellas/posts/227...  2019-02-11
# 3  https://www.facebook.com/totalbellas/posts/226...  2019-02-11
# 4  https://www.facebook.com/totalbellas/posts/226...  2019-02-10
#
#                                              message media type  reach  \
# 0  Parenting is a full-time job, and Brie is putt...       Link  30392
# 1  A media frenzy won't scare Nikki. Brie on the ...      Video  24411
# 2  From the ring to the runway, the Bella Twins a...      Video  28165
# 3  Brie’s forcing Nikki to draw a line in the san...      Video  25106
# 4  Leave a 🙏 if Mama Bella's speaking the truth.\...      Video  48040
#
#    organic impressions  engagement  organic video views  \
# 0                39400        2190                    0
# 1                31636        2055                11059
# 2                36936        2447                14166
# 3                32214       45165                 8862
# 4                63224        6236                24182
#
#    organic video completes  likes  comments  shares
# 0                        0    668        16      19
# 1                     1232    414        12      12
# 2                     1499    319         5      17
# 3                     3206   1298        89      83
# 4                    12645    869       100      58

# %%
## Create and add needed columns
fb['vis eng'] = fb['shares'] + fb['likes'] + fb['comments']
fb['engagement rate'] = fb['engagement']/fb['reach']
fb['view rate'] = fb['organic video views']/fb['organic impressions']
fb['completion rate'] = fb['organic video completes']/fb['organic impressions']
fb['answers'] = np.nan

#Phase = pre-premiere/premiere/continuity/finale
fb['phase'] = fb['date posted'].map(lambda x: "premiere" if x >= pd.to_datetime(['2019-01-10 00:00:00']) and x <= pd.to_datetime(['2019-01-16 11:59:00']) else "continuity" if (x >= pd.to_datetime(['2019-01-17 00:00:00']) and x <= pd.to_datetime(['2019-01-31 00:00:00'])) or (x >= pd.to_datetime(['2019-02-07 00:00:00']) and x <= pd.to_datetime(['2019-03-21 00:00:00'])) else "finale" if x >= pd.to_datetime(['2019-03-21 00:00:00']) and x <= pd.to_datetime(['2019-03-28 00:00:00']) else "hiatus")

#messaging = tune-in/awareness/catch-up
fb['messaging'] = fb['message'].map(lambda x: "tune-in" if 'Sunday' in x else "tune-in" if 'tomorrow' in x else "tune-in" if 'tonight' in x else "tune-in" if 'new' in x else "Catch-Up" if 'catch up' in x else "Catch-Up" if 'Demand' in x else "Awareness")

fb['episode'] = fb['time'].map(lambda x: "403" if x >= pd.to_datetime(['2019-01-24 00:00:00']) and x <= pd.to_datetime(['2019-01-30 11:59:00']) else "404" if x >= pd.to_datetime(['2019-02-07 00:00:00']) and x <= pd.to_datetime(['2019-02-13 11:59:00']) else "none")

fb['content series'] = np.nan

fb['asset type'] = np.nan

fb['subject'] = np.nan

fb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 23 columns):
# link                       35 non-null object
# date posted                35 non-null datetime64[ns]
# message                    35 non-null object
# media type                 35 non-null object
# reach                      35 non-null int64
# organic impressions        35 non-null int64
# engagement                 35 non-null int64
# organic video views        35 non-null int64
# organic video completes    35 non-null int64
# likes                      35 non-null int64
# comments                   35 non-null int64
# shares                     35 non-null int64
# vis eng                    35 non-null int64
# engagement rate            35 non-null float64
# view rate                  35 non-null float64
# completion rate            35 non-null float64
# answers                    0 non-null float64
# phase                      35 non-null object
# messaging                  35 non-null object
# episode                    35 non-null object
# content series             0 non-null float64
# asset type                 0 non-null float64
# subject                    0 non-null float64
# dtypes: datetime64[ns](1), float64(7), int64(9), object(6)
# memory usage: 6.4+ KB

# %%
# reorder columns
fb = fb[['date posted','link','message','episode','media type','phase','messaging','content series','asset type','subject','reach','organic impressions','shares','likes','comments','answers','vis eng','engagement','engagement rate','organic video views','organic video completes','view rate','completion rate']]
fb.head()
# Out:
#   date posted                                               link  \
# 0  2019-02-13  https://www.facebook.com/totalbellas/posts/227...
# 1  2019-02-12  https://www.facebook.com/totalbellas/posts/226...
# 2  2019-02-11  https://www.facebook.com/totalbellas/posts/227...
# 3  2019-02-11  https://www.facebook.com/totalbellas/posts/226...
# 4  2019-02-10  https://www.facebook.com/totalbellas/posts/226...
#
#                                              message episode media type  \
# 0  Parenting is a full-time job, and Brie is putt...     404       Link
# 1  A media frenzy won't scare Nikki. Brie on the ...     404      Video
# 2  From the ring to the runway, the Bella Twins a...     404      Video
# 3  Brie’s forcing Nikki to draw a line in the san...     404      Video
# 4  Leave a 🙏 if Mama Bella's speaking the truth.\...     404      Video
#
#         phase  messaging  content series  asset type  subject  \
# 0  continuity  Awareness             NaN         NaN      NaN
# 1  continuity   Catch-Up             NaN         NaN      NaN
# 2  continuity  Awareness             NaN         NaN      NaN
# 3  continuity   Catch-Up             NaN         NaN      NaN
# 4  continuity    tune-in             NaN         NaN      NaN
#
#         ...         likes  comments  answers  vis eng  engagement  \
# 0       ...           668        16      NaN      703        2190
# 1       ...           414        12      NaN      438        2055
# 2       ...           319         5      NaN      341        2447
# 3       ...          1298        89      NaN     1470       45165
# 4       ...           869       100      NaN     1027        6236
#
#    engagement rate  organic video views  organic video completes  view rate  \
# 0         0.072058                    0                        0   0.000000
# 1         0.084183                11059                     1232   0.349570
# 2         0.086881                14166                     1499   0.383528
# 3         1.798972                 8862                     3206   0.275098
# 4         0.129808                24182                    12645   0.382481
#
#    completion rate
# 0         0.000000
# 1         0.038943
# 2         0.040584
# 3         0.099522
# 4         0.200003
#
# [5 rows x 23 columns]

# %%
fb.to_csv('fb_weekly.csv')

# %% [markdown]
# ### Instagram
# Read in data export from Tracer, wrangle, and write to csv.

# %%
ig = pd.read_csv('ig_weekly_pull.csv')
print(ig.info())
ig.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 11 columns):
# Page Name              22 non-null object
# Post Created Date      22 non-null object
# Post Permalink         21 non-null object
# Post Media Type        21 non-null object
# Post Caption           21 non-null object
# Reach                  21 non-null float64
# Impressions            21 non-null float64
# Post Comments Count    21 non-null float64
# Post Like Count        21 non-null float64
# Engagement             21 non-null float64
# Video Views            21 non-null float64
# dtypes: float64(6), object(5)
# memory usage: 2.1+ KB
# None
#       Page Name Post Created Date                            Post Permalink  \
# 0  Total Bellas           1/24/19  https://www.instagram.com/p/BtBmix0hEo4/
# 1  Total Bellas           1/25/19  https://www.instagram.com/p/BtEL4GihjnT/
# 2  Total Bellas           1/27/19  https://www.instagram.com/p/BtJ9m-jhX6H/
# 3  Total Bellas           1/28/19  https://www.instagram.com/p/BtKLVVvB_8E/
# 4  Total Bellas           1/28/19  https://www.instagram.com/p/BtL5rDuh-J-/
#
#   Post Media Type                                       Post Caption  \
# 0           VIDEO  Where’s the RT button? 🤔 Tag every member of t...
# 1           VIDEO  @thenikkibella’s enjoying her own brand of the...
# 2           IMAGE  Double-tap to call shotgun for eternity 😍 #Tot...
# 3           VIDEO  😉 if you'll be watching #TotalBellas with us t...
# 4           IMAGE  Once a wrestler, now a mom, forever @thebriebe...
#
#       Reach  Impressions  Post Comments Count  Post Like Count  Engagement  \
# 0  122610.0     150510.0                115.0          12937.0     13876.0
# 1   91352.0     114871.0                 82.0           8470.0      9044.0
# 2  191644.0     231920.0                147.0          25957.0     26447.0
# 3  123998.0     154384.0                106.0           8735.0      9439.0
# 4  177148.0     210366.0                 97.0          21131.0     21540.0
#
#    Video Views
# 0      65116.0
# 1      45820.0
# 2          0.0
# 3      68080.0
# 4          0.0

# %%
#drop unwanted columns
ig.drop(columns = ['Page Name'], axis=1, inplace=True)
ig.drop(ig.index[-2:], inplace=True)
ig
# Out:
#    Post Created Date                            Post Permalink  \
# 0            1/24/19  https://www.instagram.com/p/BtBmix0hEo4/
# 1            1/25/19  https://www.instagram.com/p/BtEL4GihjnT/
# 2            1/27/19  https://www.instagram.com/p/BtJ9m-jhX6H/
# 3            1/28/19  https://www.instagram.com/p/BtKLVVvB_8E/
# 4            1/28/19  https://www.instagram.com/p/BtL5rDuh-J-/
# 5            1/29/19  https://www.instagram.com/p/BtOf9xKhBZ6/
# 6            1/31/19  https://www.instagram.com/p/BtR2NnWBWRW/
# 7             2/2/19  https://www.instagram.com/p/BtXAyEUBKNJ/
# 8             2/6/19  https://www.instagram.com/p/BtjU_hIB7Mf/
# 9             2/7/19  https://www.instagram.com/p/Btl-NSQBTtf/
# 10            2/7/19  https://www.instagram.com/p/BtlpNczBKiy/
# 11            2/8/19  https://www.instagram.com/p/BtoOEtIh1bD/
# 12            2/9/19  https://www.instagram.com/p/Btqx5GVB4l3/
# 13           2/10/19  https://www.instagram.com/p/Btt52VHBusk/
# 14           2/10/19  https://www.instagram.com/p/BttXRgghfz5/
# 15           2/10/19  https://www.instagram.com/p/BtuAspUh6Ne/
# 16           2/11/19  https://www.instagram.com/p/BtuOXFsh1ns/
# 17           2/11/19  https://www.instagram.com/p/Btv-RnnhTeD/
# 18           2/12/19  https://www.instagram.com/p/BtyhgVMhbWQ/
# 19           2/13/19  https://www.instagram.com/p/Bt1aYn0BeN8/
# 20           2/13/19  https://www.instagram.com/p/Bt1vg5zBF5O/
#
#    Post Media Type                                       Post Caption  \
# 0            VIDEO  Where’s the RT button? 🤔 Tag every member of t...
# 1            VIDEO  @thenikkibella’s enjoying her own brand of the...
# 2            IMAGE  Double-tap to call shotgun for eternity 😍 #Tot...
# 3            VIDEO  😉 if you'll be watching #TotalBellas with us t...
# 4            IMAGE  Once a wrestler, now a mom, forever @thebriebe...
# 5            IMAGE  Winston + @TheNikkiBella = our whole ❤ #TotalB...
# 6            IMAGE                           Our #wce 💜🔮 #TotalBellas
# 7            VIDEO    Can't a girl just live her life? 💁🏻#TotalBellas
# 8            IMAGE  We are living for this Baby Bellas throwback! ...
# 9            VIDEO  Tag someone that needs to see Nikki’s lunch da...
# 10           VIDEO  Is your fashion vibe more @thenikkibella or @t...
# 11           VIDEO  Is @thenikkibella about to change her relation...
# 12           VIDEO  Bryan is NOT interested in following Brie’s st...
# 13           VIDEO  The Bella twins have always looked fierce 🔥 #N...
# 14           VIDEO  Throwback to the Bellas slaying the red carpet...
# 15           IMAGE  Find yourself a girl that can wrestle 💪 as wel...
# 16           VIDEO  Leave a 🙏 if Mama Bella's speaking the truth.\...
# 17           VIDEO  Do you think Brie’s got a point? Or should Nik...
# 18           IMAGE  What pose makes you feel strong & beautiful? R...
# 19           VIDEO  Who are you asking to be your #Galentine this ...
# 20           VIDEO  Tag your brunch buddy! 🍹 (and take them to see...
#
#        Reach  Impressions  Post Comments Count  Post Like Count  Engagement  \
# 0   122610.0     150510.0                115.0          12937.0     13876.0
# 1    91352.0     114871.0                 82.0           8470.0      9044.0
# 2   191644.0     231920.0                147.0          25957.0     26447.0
# 3   123998.0     154384.0                106.0           8735.0      9439.0
# 4   177148.0     210366.0                 97.0          21131.0     21540.0
# 5    97237.0     122468.0                 46.0          11521.0     11678.0
# 6   110974.0     138466.0                 54.0          13559.0     13786.0
# 7    84842.0     111631.0                 93.0           7594.0      8118.0
# 8   139733.0     169668.0                 96.0          17480.0     17799.0
# 9   175452.0     227335.0                417.0          17657.0     18963.0
# 10   76792.0      96841.0                 84.0           7437.0      7909.0
# 11  135663.0     170679.0                197.0          10451.0     11380.0
# 12   75206.0      94689.0                 37.0           6520.0      6801.0
# 13   60027.0      75079.0                 30.0           5993.0      6297.0
# 14   93091.0     114196.0                 61.0          10877.0     11339.0
# 15  177830.0     223693.0                132.0          24154.0     24607.0
# 16  232998.0     291100.0                947.0          24843.0     27453.0
# 17   86562.0     107709.0                139.0           7410.0      7961.0
# 18  114526.0     142322.0                 89.0          15777.0     16176.0
# 19   41909.0      53052.0                 41.0           4404.0      4608.0
# 20   36229.0      46166.0                 20.0           3488.0      3587.0
#
#     Video Views
# 0       65116.0
# 1       45820.0
# 2           0.0
# 3       68080.0
# 4           0.0
# 5           0.0
# 6           0.0
# 7       51911.0
# 8           0.0
# 9      101374.0
# 10      32478.0
# 11      77840.0
# 12      36266.0
# 13      20700.0
# 14      50822.0
# 15          0.0
# 16     135059.0
# 17      42298.0
# 18          0.0
# 19      17357.0
# 20      16796.0

# %%
#rename columns
ig.columns = ['date','link','media type','caption','reach','impressions','comments','likes','engagement','video views']

# %%
#add columns
ig['vis eng'] = ig['likes'] + ig['comments']
ig['eng rate'] = ig['engagement']/ig['impressions']
ig['view rate'] = ig['video views']/ig['impressions']

ig['date'] = pd.to_datetime(ig['date'])
ig['date'] = ig['date'].dt.normalize()

#Phase = premiere/continuity/finale
ig['phase'] = ig['date'].map(lambda x: "premiere" if x >= pd.to_datetime(['2019-01-10 00:00:00']) and x <= pd.to_datetime(['2019-01-16 11:59:00']) else "continuity" if (x >= pd.to_datetime(['2019-01-17 00:00:00']) and x <= pd.to_datetime(['2019-01-31 00:00:00'])) or (x >= pd.to_datetime(['2019-02-07 00:00:00']) and x <= pd.to_datetime(['2019-03-21 00:00:00'])) else "finale" if x >= pd.to_datetime(['2019-03-21 00:00:00']) and x <= pd.to_datetime(['2019-03-28 00:00:00']) else "hiatus")

#messaging column based on caption containing certain words - tune-in/awareness/catch-up
ig['messaging'] = ig['caption'].map(lambda x: "tune-in" if 'Sunday' in x else "tune-in" if 'tomorrow' in x else "tune-in" if 'tonight' in x else "tune-in" if 'new' in x else "Catch-Up" if 'catch up' in x else "Catch-Up" if 'Demand' in x else "Awareness")

ig['episode'] = ig['date'].map(lambda x: "403" if x >= pd.to_datetime(['2019-01-24 00:00:00']) and x <= pd.to_datetime(['2019-01-30 11:59:00']) else "404" if x >= pd.to_datetime(['2019-02-07 00:00:00']) and x <= pd.to_datetime(['2019-02-13 11:59:00']) else "none")

ig['content series'] = np.nan

ig['asset type'] = np.nan

ig['subject'] = np.nan

print(ig.info())
ig
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21 entries, 0 to 20
# Data columns (total 19 columns):
# date              21 non-null datetime64[ns]
# link              21 non-null object
# media type        21 non-null object
# caption           21 non-null object
# reach             21 non-null float64
# impressions       21 non-null float64
# comments          21 non-null float64
# likes             21 non-null float64
# engagement        21 non-null float64
# video views       21 non-null float64
# vis eng           21 non-null float64
# eng rate          21 non-null float64
# view rate         21 non-null float64
# phase             21 non-null object
# messaging         21 non-null object
# episode           21 non-null object
# content series    0 non-null float64
# asset type        0 non-null float64
# subject           0 non-null float64
# dtypes: datetime64[ns](1), float64(12), object(6)
# memory usage: 3.3+ KB
# None
#          date                                      link media type  \
# 0  2019-01-24  https://www.instagram.com/p/BtBmix0hEo4/      VIDEO
# 1  2019-01-25  https://www.instagram.com/p/BtEL4GihjnT/      VIDEO
# 2  2019-01-27  https://www.instagram.com/p/BtJ9m-jhX6H/      IMAGE
# 3  2019-01-28  https://www.instagram.com/p/BtKLVVvB_8E/      VIDEO
# 4  2019-01-28  https://www.instagram.com/p/BtL5rDuh-J-/      IMAGE
# 5  2019-01-29  https://www.instagram.com/p/BtOf9xKhBZ6/      IMAGE
# 6  2019-01-31  https://www.instagram.com/p/BtR2NnWBWRW/      IMAGE
# 7  2019-02-02  https://www.instagram.com/p/BtXAyEUBKNJ/      VIDEO
# 8  2019-02-06  https://www.instagram.com/p/BtjU_hIB7Mf/      IMAGE
# 9  2019-02-07  https://www.instagram.com/p/Btl-NSQBTtf/      VIDEO
# 10 2019-02-07  https://www.instagram.com/p/BtlpNczBKiy/      VIDEO
# 11 2019-02-08  https://www.instagram.com/p/BtoOEtIh1bD/      VIDEO
# 12 2019-02-09  https://www.instagram.com/p/Btqx5GVB4l3/      VIDEO
# 13 2019-02-10  https://www.instagram.com/p/Btt52VHBusk/      VIDEO
# 14 2019-02-10  https://www.instagram.com/p/BttXRgghfz5/      VIDEO
# 15 2019-02-10  https://www.instagram.com/p/BtuAspUh6Ne/      IMAGE
# 16 2019-02-11  https://www.instagram.com/p/BtuOXFsh1ns/      VIDEO
# 17 2019-02-11  https://www.instagram.com/p/Btv-RnnhTeD/      VIDEO
# 18 2019-02-12  https://www.instagram.com/p/BtyhgVMhbWQ/      IMAGE
# 19 2019-02-13  https://www.instagram.com/p/Bt1aYn0BeN8/      VIDEO
# 20 2019-02-13  https://www.instagram.com/p/Bt1vg5zBF5O/      VIDEO
#
#                                               caption     reach  impressions  \
# 0   Where’s the RT button? 🤔 Tag every member of t...  122610.0     150510.0
# 1   @thenikkibella’s enjoying her own brand of the...   91352.0     114871.0
# 2   Double-tap to call shotgun for eternity 😍 #Tot...  191644.0     231920.0
# 3   😉 if you'll be watching #TotalBellas with us t...  123998.0     154384.0
# 4   Once a wrestler, now a mom, forever @thebriebe...  177148.0     210366.0
# 5   Winston + @TheNikkiBella = our whole ❤ #TotalB...   97237.0     122468.0
# 6                            Our #wce 💜🔮 #TotalBellas  110974.0     138466.0
# 7     Can't a girl just live her life? 💁🏻#TotalBellas   84842.0     111631.0
# 8   We are living for this Baby Bellas throwback! ...  139733.0     169668.0
# 9   Tag someone that needs to see Nikki’s lunch da...  175452.0     227335.0
# 10  Is your fashion vibe more @thenikkibella or @t...   76792.0      96841.0
# 11  Is @thenikkibella about to change her relation...  135663.0     170679.0
# 12  Bryan is NOT interested in following Brie’s st...   75206.0      94689.0
# 13  The Bella twins have always looked fierce 🔥 #N...   60027.0      75079.0
# 14  Throwback to the Bellas slaying the red carpet...   93091.0     114196.0
# 15  Find yourself a girl that can wrestle 💪 as wel...  177830.0     223693.0
# 16  Leave a 🙏 if Mama Bella's speaking the truth.\...  232998.0     291100.0
# 17  Do you think Brie’s got a point? Or should Nik...   86562.0     107709.0
# 18  What pose makes you feel strong & beautiful? R...  114526.0     142322.0
# 19  Who are you asking to be your #Galentine this ...   41909.0      53052.0
# 20  Tag your brunch buddy! 🍹 (and take them to see...   36229.0      46166.0
#
#     comments    likes  engagement  video views  vis eng  eng rate  view rate  \
# 0      115.0  12937.0     13876.0      65116.0  13052.0  0.092193   0.432636
# 1       82.0   8470.0      9044.0      45820.0   8552.0  0.078732   0.398882
# 2      147.0  25957.0     26447.0          0.0  26104.0  0.114035   0.000000
# 3      106.0   8735.0      9439.0      68080.0   8841.0  0.061140   0.440978
# 4       97.0  21131.0     21540.0          0.0  21228.0  0.102393   0.000000
# 5       46.0  11521.0     11678.0          0.0  11567.0  0.095356   0.000000
# 6       54.0  13559.0     13786.0          0.0  13613.0  0.099562   0.000000
# 7       93.0   7594.0      8118.0      51911.0   7687.0  0.072722   0.465023
# 8       96.0  17480.0     17799.0          0.0  17576.0  0.104905   0.000000
# 9      417.0  17657.0     18963.0     101374.0  18074.0  0.083414   0.445923
# 10      84.0   7437.0      7909.0      32478.0   7521.0  0.081670   0.335374
# 11     197.0  10451.0     11380.0      77840.0  10648.0  0.066675   0.456061
# 12      37.0   6520.0      6801.0      36266.0   6557.0  0.071825   0.383001
# 13      30.0   5993.0      6297.0      20700.0   6023.0  0.083872   0.275710
# 14      61.0  10877.0     11339.0      50822.0  10938.0  0.099294   0.445042
# 15     132.0  24154.0     24607.0          0.0  24286.0  0.110003   0.000000
# 16     947.0  24843.0     27453.0     135059.0  25790.0  0.094308   0.463961
# 17     139.0   7410.0      7961.0      42298.0   7549.0  0.073912   0.392706
# 18      89.0  15777.0     16176.0          0.0  15866.0  0.113658   0.000000
# 19      41.0   4404.0      4608.0      17357.0   4445.0  0.086858   0.327170
# 20      20.0   3488.0      3587.0      16796.0   3508.0  0.077698   0.363818
#
#          phase  messaging episode  content series  asset type  subject
# 0   continuity    tune-in     403             NaN         NaN      NaN
# 1   continuity    tune-in     403             NaN         NaN      NaN
# 2   continuity  Awareness     403             NaN         NaN      NaN
# 3   continuity    tune-in     403             NaN         NaN      NaN
# 4   continuity  Awareness     403             NaN         NaN      NaN
# 5   continuity  Awareness     403             NaN         NaN      NaN
# 6   continuity  Awareness    none             NaN         NaN      NaN
# 7       hiatus  Awareness    none             NaN         NaN      NaN
# 8       hiatus  Awareness    none             NaN         NaN      NaN
# 9   continuity    tune-in     404             NaN         NaN      NaN
# 10  continuity  Awareness     404             NaN         NaN      NaN
# 11  continuity  Awareness     404             NaN         NaN      NaN
# 12  continuity  Awareness     404             NaN         NaN      NaN
# 13  continuity  Awareness     404             NaN         NaN      NaN
# 14  continuity    tune-in     404             NaN         NaN      NaN
# 15  continuity  Awareness     404             NaN         NaN      NaN
# 16  continuity    tune-in     404             NaN         NaN      NaN
# 17  continuity  Awareness     404             NaN         NaN      NaN
# 18  continuity  Awareness     404             NaN         NaN      NaN
# 19  continuity  Awareness     404             NaN         NaN      NaN
# 20  continuity  Awareness     404             NaN         NaN      NaN

# %%
#reorder columns
ig = ig[['date','link','media type','caption','episode','phase','messaging','content series','asset type','subject','reach','impressions','engagement','eng rate','likes','comments','vis eng','video views','view rate']]

ig.head()
# Out:
#         date                                      link media type  \
# 0 2019-01-24  https://www.instagram.com/p/BtBmix0hEo4/      VIDEO
# 1 2019-01-25  https://www.instagram.com/p/BtEL4GihjnT/      VIDEO
# 2 2019-01-27  https://www.instagram.com/p/BtJ9m-jhX6H/      IMAGE
# 3 2019-01-28  https://www.instagram.com/p/BtKLVVvB_8E/      VIDEO
# 4 2019-01-28  https://www.instagram.com/p/BtL5rDuh-J-/      IMAGE
#
#                                              caption episode       phase  \
# 0  Where’s the RT button? 🤔 Tag every member of t...     403  continuity
# 1  @thenikkibella’s enjoying her own brand of the...     403  continuity
# 2  Double-tap to call shotgun for eternity 😍 #Tot...     403  continuity
# 3  😉 if you'll be watching #TotalBellas with us t...     403  continuity
# 4  Once a wrestler, now a mom, forever @thebriebe...     403  continuity
#
#    messaging  content series  asset type  subject     reach  impressions  \
# 0    tune-in             NaN         NaN      NaN  122610.0     150510.0
# 1    tune-in             NaN         NaN      NaN   91352.0     114871.0
# 2  Awareness             NaN         NaN      NaN  191644.0     231920.0
# 3    tune-in             NaN         NaN      NaN  123998.0     154384.0
# 4  Awareness             NaN         NaN      NaN  177148.0     210366.0
#
#    engagement  eng rate    likes  comments  vis eng  video views  view rate
# 0     13876.0  0.092193  12937.0     115.0  13052.0      65116.0   0.432636
# 1      9044.0  0.078732   8470.0      82.0   8552.0      45820.0   0.398882
# 2     26447.0  0.114035  25957.0     147.0  26104.0          0.0   0.000000
# 3      9439.0  0.061140   8735.0     106.0   8841.0      68080.0   0.440978
# 4     21540.0  0.102393  21131.0      97.0  21228.0          0.0   0.000000

# %%
#write to csv
ig.to_csv('ig_weekly.csv')
